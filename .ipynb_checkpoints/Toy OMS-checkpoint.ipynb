# %%
import pandas as pd
import numpy as np
import re as re
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Run .json file

# %%
file="collisions/oms_runs.json"
# file=open(path+"oms_runs.json")

# %%
df=pd.read_json(file)
df.columns
# Out:
# Index(['components', 'l1_hlt_mode_stripped', 'l1_key', 'duration', 'b_field',
#        'tier0_transfer', 'l1_triggers_counter', 'hlt_physics_throughput',
#        'init_lumi', 'last_update', 'beamactive_total_deadtime',
#        'delivered_lumi', 'recorded_lumi', 'cmssw_version', 'energy',
#        'end_lumi', 'hlt_physics_rate', 'fill_number', 'l1_hlt_mode',
#        'end_time', 'trigger_mode', 'l1_key_stripped', 'fill_type_party2',
#        'fill_type_party1', 'initial_prescale_index', 'sequence', 'start_time',
#        'hlt_physics_size', 'fill_type_runtime', 'hlt_key', 'clock_type',
#        'last_lumisection_number', 'l1_rate', 'l1_menu', 'run_number',
#        'stable_beam', 'hlt_physics_counter', 'init_lumi_unit',
#        'delivered_lumi_unit', 'recorded_lumi_unit', 'end_lumi_unit'],
#       dtype='object')

# %%
df[["run_number",'l1_rate',"l1_key",]]
# Out:
#    run_number    l1_rate                     l1_key
# 0      315264  48897.560  l1_trg_collisions2018/v10
# 1      315265  44289.950  l1_trg_collisions2018/v10
# 2      315266        NaN  l1_trg_collisions2018/v10
# 3      315267  40882.477  l1_trg_collisions2018/v10
# 4      315268      4.161  l1_trg_collisions2018/v10
# 5      315269        NaN  l1_trg_collisions2018/v10
# 6      315270  33561.880  l1_trg_collisions2018/v10
# 7      315273  30617.836  l1_trg_collisions2018/v10

# %% [markdown]
# ## per fill .json file

# %%
file="collisions/oms_fills.json"
# file=open(path+"oms_runs.json")

# %%
df=pd.read_json(file)
print(df.columns)
print(df.shape)
# Out:
# Index(['peak_lumi', 'bunches_colliding', 'intensity_beam2', 'intensity_beam1',
#        'to_ready_time', 'crossing_angle', 'dump_ready_to_dump_time',
#        'end_stable_beam', 'duration', 'b_field', 'stop_crossing_angle',
#        'beta_star', 'init_lumi', 'era', 'peak_specific_lumi', 'bunches_target',
#        'injection_scheme', 'stable_beams', 'delivered_lumi', 'recorded_lumi',
#        'last_run_number', 'energy', 'fill_number', 'start_crossing_angle',
#        'efficiency_time', 'to_dump_ready_time', 'end_time', 'fill_type_party2',
#        'fill_type_party1', 'beta_star_start', 'start_time', 'downtime',
#        'peak_pileup', 'fill_type_runtime', 'first_run_number', 'bunches_beam1',
#        'start_stable_beam', 'bunches_beam2', 'efficiency_lumi',
#        'beta_star_stop', 'start_crossing_angle_unit', 'peak_lumi_unit',
#        'intensity_beam2_unit', 'intensity_beam1_unit', 'crossing_angle_unit',
#        'beta_star_start_unit', 'stop_crossing_angle_unit', 'beta_star_unit',
#        'init_lumi_unit', 'peak_specific_lumi_unit', 'delivered_lumi_unit',
#        'recorded_lumi_unit', 'beta_star_stop_unit'],
#       dtype='object')
# (3, 53)

# %%
df[['peak_lumi', 'bunches_colliding', 'intensity_beam2', 'intensity_beam1',
       'to_ready_time', 'crossing_angle', 'dump_ready_to_dump_time',
       'end_stable_beam', 'duration', 'b_field', 'stop_crossing_angle',
       'beta_star', 'init_lumi', 'era', 'peak_specific_lumi', 'bunches_target',
       'injection_scheme', 'stable_beams', 'delivered_lumi', 'recorded_lumi',
       'last_run_number', 'energy', 'fill_number', 'start_crossing_angle',
       'efficiency_time', 'to_dump_ready_time', 'end_time', 'fill_type_party2',
       'fill_type_party1', 'beta_star_start', 'start_time', 'downtime',
       'peak_pileup', 'fill_type_runtime', 'first_run_number', 'bunches_beam1',
       'start_stable_beam', 'bunches_beam2', 'efficiency_lumi',
       'beta_star_stop', 'start_crossing_angle_unit', 'peak_lumi_unit',
       'intensity_beam2_unit', 'intensity_beam1_unit', 'crossing_angle_unit',
       'beta_star_start_unit', 'stop_crossing_angle_unit', 'beta_star_unit',
       'init_lumi_unit', 'peak_specific_lumi_unit', 'delivered_lumi_unit',
       'recorded_lumi_unit', 'beta_star_stop_unit']]
# Out:
#    peak_lumi  bunches_colliding  intensity_beam2  intensity_beam1  \
# 0   0.530741                590        741.58323        742.49994
# 1   0.843972                974       1224.96922       1210.63980
# 2   0.820939                974       1224.89263       1187.55712
#
#    to_ready_time  crossing_angle  dump_ready_to_dump_time  \
# 0        132.620             160                  162.168
# 1         55.579             160                 1668.805
# 2         49.177             160                   93.987
#
#         end_stable_beam  duration  b_field  stop_crossing_angle  beta_star  \
# 0  2018-04-26T23:04:52Z     18647    3.801                  160         30
# 1  2018-04-27T11:18:38Z     30864    3.801                  160         30
# 2  2018-04-27T23:21:21Z     31242    3.801                  160         30
#
#    init_lumi    era  peak_specific_lumi  bunches_target  \
# 0   0.000002  2018A            5.855298             590
# 1   0.000002  2018A            5.623842             974
# 2   0.000006  2018A            5.569620             974
#
#                      injection_scheme  stable_beams  delivered_lumi  \
# 0   25ns_603b_590_526_547_96bpi_13inj          True       78.084328
# 1   25ns_987b_974_876_912_96bpi_17inj          True      181.210906
# 2  25ns_987b_974_878_917_144bpi_13inj          True      181.601438
#
#    recorded_lumi  last_run_number   energy  fill_number  start_crossing_angle  \
# 0      57.996832           315259  6499.32         6615                   160
# 1     160.616000           315273  6499.32         6616                   160
# 2     177.182328           315322  6499.32         6617                   160
#
#    efficiency_time  to_dump_ready_time                  end_time  \
# 0           77.597               218.0 2018-04-26 23:09:44+00:00
# 1           91.724                 NaN 2018-04-27 11:23:34+00:00
# 2           99.839               220.0 2018-04-27 23:28:04+00:00
#
#   fill_type_party2 fill_type_party1  beta_star_start  \
# 0           PROTON           PROTON              NaN
# 1           PROTON           PROTON              NaN
# 2           PROTON           PROTON              NaN
#
#                  start_time  downtime  peak_pileup fill_type_runtime  \
# 0 2018-04-26 07:15:48+00:00      4177    63.993752           PROTONS
# 1 2018-04-26 23:09:44+00:00      2554    61.705254           PROTONS
# 2 2018-04-27 11:23:34+00:00        50    59.959625           PROTONS
#
#    first_run_number  bunches_beam1     start_stable_beam  bunches_beam2  \
# 0            315193            603  2018-04-26T17:54:05Z            603
# 1            315260            987  2018-04-27T02:44:14Z            987
# 2            315274            987  2018-04-27T14:40:39Z            987
#
#    efficiency_lumi  beta_star_stop start_crossing_angle_unit  \
# 0           74.275             NaN                  {\mu}rad
# 1           88.635             NaN                  {\mu}rad
# 2           97.567             NaN                  {\mu}rad
#
#          peak_lumi_unit intensity_beam2_unit intensity_beam1_unit  \
# 0  10^{34}cm^{-2}s^{-1}              10^{11}              10^{11}
# 1  10^{34}cm^{-2}s^{-1}              10^{11}              10^{11}
# 2  10^{34}cm^{-2}s^{-1}              10^{11}              10^{11}
#
#   crossing_angle_unit beta_star_start_unit stop_crossing_angle_unit  \
# 0            {\mu}rad                   cm                 {\mu}rad
# 1            {\mu}rad                   cm                 {\mu}rad
# 2            {\mu}rad                   cm                 {\mu}rad
#
#   beta_star_unit        init_lumi_unit              peak_specific_lumi_unit  \
# 0             cm  10^{34}cm^{-2}s^{-1}  10^{30}cm^{-2}s^{-1}(10^{11}p)^{-2}
# 1             cm  10^{34}cm^{-2}s^{-1}  10^{30}cm^{-2}s^{-1}(10^{11}p)^{-2}
# 2             cm  10^{34}cm^{-2}s^{-1}  10^{30}cm^{-2}s^{-1}(10^{11}p)^{-2}
#
#   delivered_lumi_unit recorded_lumi_unit beta_star_stop_unit
# 0             pb^{-1}            pb^{-1}                  cm
# 1             pb^{-1}            pb^{-1}                  cm
# 2             pb^{-1}            pb^{-1}                  cm

# %% [markdown]
# ----

# %% [markdown]
# ## Per Lumi .json file

# %%
file="collisions/oms_hltrates.json"
# file=open(path+"oms_runs.json")

# %%
df=pd.read_json(file)
print(df.columns)
print(df.shape)
# Out:
# Index(['fill_number', 'start_time', 'last_lumisection_number', 'rate',
#        'run_number', 'last_lumisection_in_run', 'first_lumisection_number',
#        'counter', 'path_name'],
#       dtype='object')
# (23180, 9)

# %%
slimdf=df[["rate","last_lumisection_number","rate","run_number","counter","path_name"]]
# Out:
#        fill_number                start_time  last_lumisection_number  \
# 0             6616 2018-04-27 11:05:03+00:00                       10
# 1             6616 2018-04-27 11:05:26+00:00                       11
# 2             6616 2018-04-27 11:05:49+00:00                       12
# 3             6616 2018-04-27 11:06:12+00:00                       13
# 4             6616 2018-04-27 11:06:36+00:00                       14
# ...            ...                       ...                      ...
# 23175         6616 2018-04-27 11:17:52+00:00                       43
# 23176         6616 2018-04-27 11:18:15+00:00                       44
# 23177         6616 2018-04-27 11:18:38+00:00                       45
# 23178         6616 2018-04-27 11:19:02+00:00                       46
# 23179         6616 2018-04-27 11:19:25+00:00                       47
#
#              rate  run_number  last_lumisection_in_run  \
# 0      588.406650      315273                       47
# 1      593.082672      315273                       47
# 2      589.951024      315273                       47
# 3      591.795693      315273                       47
# 4      574.893373      315273                       47
# ...           ...         ...                      ...
# 23175    0.000000      315273                       47
# 23176    0.000000      315273                       47
# 23177    0.000000      315273                       47
# 23178    0.000000      315273                       47
# 23179    0.000000      315273                       47
#
#        first_lumisection_number  counter               path_name
# 0                            10    13716  AlCa_EcalEtaEBonly_v12
# 1                            11    13825  AlCa_EcalEtaEBonly_v12
# 2                            12    13752  AlCa_EcalEtaEBonly_v12
# 3                            13    13795  AlCa_EcalEtaEBonly_v12
# 4                            14    13401  AlCa_EcalEtaEBonly_v12
# ...                         ...      ...                     ...
# 23175                        43        0      HLTriggerFirstPath
# 23176                        44        0      HLTriggerFirstPath
# 23177                        45        0      HLTriggerFirstPath
# 23178                        46        0      HLTriggerFirstPath
# 23179                        47        0      HLTriggerFirstPath
#
# [23180 rows x 9 columns]

# %%
df["path_name"].unique()
# Out:
# array(['AlCa_EcalEtaEBonly_v12', 'AlCa_EcalEtaEEonly_v12',
#        'AlCa_EcalPhiSym_v8', 'AlCa_EcalPi0EBonly_v12',
#        'AlCa_EcalPi0EEonly_v12', 'AlCa_LumiPixels_Random_v4',
#        'AlCa_LumiPixels_ZeroBias_v8', 'AlCa_RPCMuonNormalisation_v13',
#        'DST_CaloJet40_BTagScouting_v13',
#        'DST_CaloJet40_CaloBTagScouting_v12',
#        'DST_CaloJet40_CaloScouting_PFScouting_v13',
#        'DST_DoubleMu1_noVtx_CaloScouting_v1',
#        'DST_DoubleMu3_noVtx_CaloScouting_Monitoring_v5',
#        'DST_DoubleMu3_noVtx_CaloScouting_v5',
#        'DST_DoubleMu3_noVtx_Mass10_PFScouting_v1',
#        'DST_HT250_CaloBTagScouting_v8', 'DST_HT250_CaloScouting_v9',
#        'DST_HT410_BTagScouting_v14', 'DST_HT410_PFScouting_v14',
#        'DST_L1DoubleMu_BTagScouting_v14',
#        'DST_L1DoubleMu_CaloScouting_PFScouting_v13',
#        'DST_L1HTT_BTagScouting_v13', 'DST_L1HTT_CaloBTagScouting_v12',
#        'DST_L1HTT_CaloScouting_PFScouting_v13', 'DST_Physics_v7',
#        'DST_ZeroBias_BTagScouting_v13',
#        'DST_ZeroBias_CaloScouting_PFScouting_v12', 'DST_ZeroBias_v2',
#        'HLT_AK4CaloJet100_v10', 'HLT_AK4CaloJet120_v9',
#        'HLT_AK4CaloJet30_v11', 'HLT_AK4CaloJet40_v10',
#        'HLT_AK4CaloJet50_v10', 'HLT_AK4CaloJet80_v10',
#        'HLT_AK4PFJet100_v17', 'HLT_AK4PFJet120_v16', 'HLT_AK4PFJet30_v17',
#        'HLT_AK4PFJet50_v17', 'HLT_AK4PFJet80_v17',
#        'HLT_AK8PFHT750_TrimMass50_v10', 'HLT_AK8PFHT800_TrimMass50_v10',
#        'HLT_AK8PFHT850_TrimMass50_v9', 'HLT_AK8PFHT900_TrimMass50_v9',
#        'HLT_AK8PFJet140_v13', 'HLT_AK8PFJet15_v1', 'HLT_AK8PFJet200_v13',
#        'HLT_AK8PFJet25_v1', 'HLT_AK8PFJet260_v14', 'HLT_AK8PFJet320_v14',
#        'HLT_AK8PFJet330_TrimMass30_PFAK8BTagCSV_p17_v1',
#        'HLT_AK8PFJet330_TrimMass30_PFAK8BTagCSV_p1_v1',
#        'HLT_AK8PFJet330_TrimMass30_PFAK8BoostedDoubleB_p02_v1',
#        'HLT_AK8PFJet360_TrimMass30_v16', 'HLT_AK8PFJet380_TrimMass30_v9',
#        'HLT_AK8PFJet400_TrimMass30_v10', 'HLT_AK8PFJet400_v14',
#        'HLT_AK8PFJet40_v14', 'HLT_AK8PFJet420_TrimMass30_v9',
#        'HLT_AK8PFJet450_v14', 'HLT_AK8PFJet500_v14', 'HLT_AK8PFJet550_v9',
#        'HLT_AK8PFJet60_v13', 'HLT_AK8PFJet80_v13',
#        'HLT_AK8PFJetFwd140_v12', 'HLT_AK8PFJetFwd15_v1',
#        'HLT_AK8PFJetFwd200_v12', 'HLT_AK8PFJetFwd25_v1',
#        'HLT_AK8PFJetFwd260_v13', 'HLT_AK8PFJetFwd320_v13',
#        'HLT_AK8PFJetFwd400_v13', 'HLT_AK8PFJetFwd40_v13',
#        'HLT_AK8PFJetFwd450_v13', 'HLT_AK8PFJetFwd500_v13',
#        'HLT_AK8PFJetFwd60_v12', 'HLT_AK8PFJetFwd80_v12',
#        'HLT_BTagMu_AK4DiJet110_Mu5_v11', 'HLT_BTagMu_AK4DiJet170_Mu5_v10',
#        'HLT_BTagMu_AK4DiJet20_Mu5_v11', 'HLT_BTagMu_AK4DiJet40_Mu5_v11',
#        'HLT_BTagMu_AK4DiJet70_Mu5_v11', 'HLT_BTagMu_AK4Jet300_Mu5_v11',
#        'HLT_BTagMu_AK8DiJet170_Mu5_v7', 'HLT_BTagMu_AK8Jet300_Mu5_v11',
#        'HLT_CaloJet500_NoJetID_v11', 'HLT_CaloJet550_NoJetID_v6',
#        'HLT_CaloMET100_HBHECleaned_v3', 'HLT_CaloMET100_NotCleaned_v3',
#        'HLT_CaloMET110_NotCleaned_v3', 'HLT_CaloMET250_HBHECleaned_v3',
#        'HLT_CaloMET250_NotCleaned_v3', 'HLT_CaloMET300_HBHECleaned_v3',
#        'HLT_CaloMET350_HBHECleaned_v3', 'HLT_CaloMET70_HBHECleaned_v3',
#        'HLT_CaloMET80_HBHECleaned_v3', 'HLT_CaloMET80_NotCleaned_v3',
#        'HLT_CaloMET90_HBHECleaned_v3', 'HLT_CaloMET90_NotCleaned_v3',
#        'HLT_CaloMHT90_v3', 'HLT_DiEle27_WPTightCaloOnly_L1DoubleEG_v3',
#        'HLT_DiJet110_35_Mjj650_PFMET110_v7',
#        'HLT_DiJet110_35_Mjj650_PFMET120_v7',
#        'HLT_DiJet110_35_Mjj650_PFMET130_v7',
#        'HLT_DiMu9_Ele9_CaloIdL_TrackIdL_DZ_v15',
#        'HLT_DiMu9_Ele9_CaloIdL_TrackIdL_v15',
#        'HLT_DiPFJet15_FBEta3_NoCaloMatched_v15',
#        'HLT_DiPFJet15_NoCaloMatched_v14',
#        'HLT_DiPFJet25_FBEta3_NoCaloMatched_v15',
#        'HLT_DiPFJet25_NoCaloMatched_v14', 'HLT_DiPFJetAve100_HFJEC_v13',
#        'HLT_DiPFJetAve140_v11', 'HLT_DiPFJetAve15_HFJEC_v15',
#        'HLT_DiPFJetAve160_HFJEC_v13', 'HLT_DiPFJetAve200_v11',
#        'HLT_DiPFJetAve220_HFJEC_v14', 'HLT_DiPFJetAve25_HFJEC_v15',
#        'HLT_DiPFJetAve260_v12', 'HLT_DiPFJetAve300_HFJEC_v14',
#        'HLT_DiPFJetAve320_v12', 'HLT_DiPFJetAve35_HFJEC_v15',
#        'HLT_DiPFJetAve400_v12', 'HLT_DiPFJetAve40_v12',
#        'HLT_DiPFJetAve500_v12', 'HLT_DiPFJetAve60_HFJEC_v13',
#        'HLT_DiPFJetAve60_v12', 'HLT_DiPFJetAve80_HFJEC_v13',
#        'HLT_DiPFJetAve80_v11', 'HLT_DiSC30_18_EIso_AND_HE_Mass70_v12',
#        'HLT_Dimuon0_Jpsi3p5_Muon2_v5',
#        'HLT_Dimuon0_Jpsi_L1_4R_0er1p5R_v6', 'HLT_Dimuon0_Jpsi_L1_NoOS_v6',
#        'HLT_Dimuon0_Jpsi_NoVertexing_L1_4R_0er1p5R_v6',
#        'HLT_Dimuon0_Jpsi_NoVertexing_NoOS_v6',
#        'HLT_Dimuon0_Jpsi_NoVertexing_v7', 'HLT_Dimuon0_Jpsi_v7',
#        'HLT_Dimuon0_LowMass_L1_0er1p5R_v6',
#        'HLT_Dimuon0_LowMass_L1_0er1p5_v7', 'HLT_Dimuon0_LowMass_L1_4R_v6',
#        'HLT_Dimuon0_LowMass_L1_4_v7', 'HLT_Dimuon0_LowMass_L1_TM530_v5',
#        'HLT_Dimuon0_LowMass_v7', 'HLT_Dimuon0_Upsilon_L1_4p5NoOS_v6',
#        'HLT_Dimuon0_Upsilon_L1_4p5_v7',
#        'HLT_Dimuon0_Upsilon_L1_4p5er2p0M_v6',
#        'HLT_Dimuon0_Upsilon_L1_4p5er2p0_v7',
#        'HLT_Dimuon0_Upsilon_L1_5M_v6', 'HLT_Dimuon0_Upsilon_L1_5_v7',
#        'HLT_Dimuon0_Upsilon_Muon_L1_TM0_v5',
#        'HLT_Dimuon0_Upsilon_Muon_NoL1Mass_v5',
#        'HLT_Dimuon0_Upsilon_NoVertexing_v6',
#        'HLT_Dimuon10_PsiPrime_Barrel_Seagulls_v6',
#        'HLT_Dimuon10_Upsilon_Barrel_Seagulls_v6',
#        'HLT_Dimuon12_Upsilon_eta1p5_v13',
#        'HLT_Dimuon14_Phi_Barrel_Seagulls_v6',
#        'HLT_Dimuon18_PsiPrime_noCorrL1_v4', 'HLT_Dimuon18_PsiPrime_v13',
#        'HLT_Dimuon20_Jpsi_Barrel_Seagulls_v6',
#        'HLT_Dimuon24_Phi_noCorrL1_v4', 'HLT_Dimuon24_Upsilon_noCorrL1_v4',
#        'HLT_Dimuon25_Jpsi_noCorrL1_v4', 'HLT_Dimuon25_Jpsi_v13',
#        'HLT_Diphoton30EB_18EB_R9Id_OR_IsoCaloId_AND_HE_R9Id_NoPixelVeto_Mass55_v12',
#        'HLT_Diphoton30EB_18EB_R9Id_OR_IsoCaloId_AND_HE_R9Id_PixelVeto_Mass55_v13',
#        'HLT_Diphoton30PV_18PV_R9Id_AND_IsoCaloId_AND_HE_R9Id_NoPixelVeto_Mass55_v12',
#        'HLT_Diphoton30PV_18PV_R9Id_AND_IsoCaloId_AND_HE_R9Id_PixelVeto_Mass55_v13',
#        'HLT_Diphoton30_18_PVrealAND_R9Id_AND_IsoCaloId_AND_HE_R9Id_NoPixelVeto_Mass55_v8',
#        'HLT_Diphoton30_18_PVrealAND_R9Id_AND_IsoCaloId_AND_HE_R9Id_PixelVeto_Mass55_v8',
#        'HLT_Diphoton30_22_R9Id_OR_IsoCaloId_AND_HE_R9Id_Mass90_v12',
#        'HLT_Diphoton30_22_R9Id_OR_IsoCaloId_AND_HE_R9Id_Mass95_v12',
#        'HLT_DoubleEle24_eta2p1_WPTight_Gsf_v5',
#        'HLT_DoubleEle25_CaloIdL_MW_v2', 'HLT_DoubleEle27_CaloIdL_MW_v2',
#        'HLT_DoubleEle33_CaloIdL_MW_v15',
#        'HLT_DoubleEle8_CaloIdM_TrackIdM_Mass8_DZ_PFHT350_v18',
#        'HLT_DoubleEle8_CaloIdM_TrackIdM_Mass8_PFHT350_v18',
#        'HLT_DoubleIsoMu20_eta2p1_v5', 'HLT_DoubleIsoMu24_eta2p1_v5',
#        'HLT_DoubleL2Mu23NoVtx_2Cha_CosmicSeed_v1',
#        'HLT_DoubleL2Mu23NoVtx_2Cha_v1',
#        'HLT_DoubleL2Mu25NoVtx_2Cha_CosmicSeed_Eta2p4_v1',
#        'HLT_DoubleL2Mu25NoVtx_2Cha_CosmicSeed_v1',
#        'HLT_DoubleL2Mu25NoVtx_2Cha_Eta2p4_v1',
#        'HLT_DoubleL2Mu25NoVtx_2Cha_v1',
#        'HLT_DoubleL2Mu30NoVtx_2Cha_CosmicSeed_Eta2p4_v1',
#        'HLT_DoubleL2Mu30NoVtx_2Cha_Eta2p4_v1', 'HLT_DoubleL2Mu50_v2',
#        'HLT_DoubleMediumChargedIsoPFTau35_Trk1_TightID_eta2p1_Reg_v10',
#        'HLT_DoubleMediumChargedIsoPFTau35_Trk1_eta2p1_Reg_v10',
#        'HLT_DoubleMediumChargedIsoPFTau40_Trk1_TightID_eta2p1_Reg_v10',
#        'HLT_DoubleMediumChargedIsoPFTau40_Trk1_eta2p1_Reg_v10',
#        'HLT_DoubleMediumChargedIsoPFTauHPS35_Trk1_eta2p1_Reg_v1',
#        'HLT_DoubleMu20_7_Mass0to30_L1_DM4EG_v6',
#        'HLT_DoubleMu20_7_Mass0to30_L1_DM4_v6',
#        'HLT_DoubleMu20_7_Mass0to30_Photon23_v6',
#        'HLT_DoubleMu2_Jpsi_DoubleTkMu0_Phi_v3',
#        'HLT_DoubleMu2_Jpsi_DoubleTrk1_Phi1p05_v5',
#        'HLT_DoubleMu3_DCA_PFMET50_PFMHT60_v8',
#        'HLT_DoubleMu3_DZ_PFMET50_PFMHT60_v8',
#        'HLT_DoubleMu3_DZ_PFMET70_PFMHT70_v8',
#        'HLT_DoubleMu3_DZ_PFMET90_PFMHT90_v8',
#        'HLT_DoubleMu3_DoubleEle7p5_CaloIdL_TrackIdL_Upsilon_v2',
#        'HLT_DoubleMu3_TkMu_DsTau3Mu_v2',
#        'HLT_DoubleMu3_Trk_Tau3mu_NoL1Mass_v5',
#        'HLT_DoubleMu3_Trk_Tau3mu_v11', 'HLT_DoubleMu43NoFiltersNoVtx_v3',
#        'HLT_DoubleMu48NoFiltersNoVtx_v3', 'HLT_DoubleMu4_3_Bs_v13',
#        'HLT_DoubleMu4_3_Jpsi_v1', 'HLT_DoubleMu4_JpsiTrkTrk_Displaced_v6',
#        'HLT_DoubleMu4_JpsiTrk_Displaced_v14',
#        'HLT_DoubleMu4_Jpsi_Displaced_v6',
#        'HLT_DoubleMu4_Jpsi_NoVertexing_v6',
#        'HLT_DoubleMu4_LowMassNonResonantTrk_Displaced_v14',
#        'HLT_DoubleMu4_Mass8_DZ_PFHT350_v7',
#        'HLT_DoubleMu4_PsiPrimeTrk_Displaced_v14',
#        'HLT_DoubleMu5_Upsilon_DoubleEle3_CaloIdL_TrackIdL_v2',
#        'HLT_DoubleMu8_Mass8_PFHT350_v7',
#        'HLT_DoublePFJets100_CaloBTagCSV_p79_v1',
#        'HLT_DoublePFJets116MaxDeta1p6_DoubleCaloBTagCSV_p79_v1',
#        'HLT_DoublePFJets128MaxDeta1p6_DoubleCaloBTagCSV_p79_v1',
#        'HLT_DoublePFJets200_CaloBTagCSV_p79_v1',
#        'HLT_DoublePFJets350_CaloBTagCSV_p79_v1',
#        'HLT_DoublePFJets40_CaloBTagCSV_p79_v1',
#        'HLT_DoublePhoton33_CaloIdL_v5', 'HLT_DoublePhoton70_v5',
#        'HLT_DoublePhoton85_v13',
#        'HLT_DoubleTightChargedIsoPFTau35_Trk1_TightID_eta2p1_Reg_v10',
#        'HLT_DoubleTightChargedIsoPFTau35_Trk1_eta2p1_Reg_v10',
#        'HLT_DoubleTightChargedIsoPFTau40_Trk1_TightID_eta2p1_Reg_v10',
#        'HLT_DoubleTightChargedIsoPFTau40_Trk1_eta2p1_Reg_v10',
#        'HLT_ECALHT800_v9', 'HLT_EcalCalibration_v4',
#        'HLT_Ele115_CaloIdVT_GsfTrkIdT_v12',
#        'HLT_Ele12_CaloIdL_TrackIdL_IsoVL_PFJet30_v16',
#        'HLT_Ele135_CaloIdVT_GsfTrkIdT_v5',
#        'HLT_Ele145_CaloIdVT_GsfTrkIdT_v6',
#        'HLT_Ele15_CaloIdL_TrackIdL_IsoVL_PFJet30_v1',
#        'HLT_Ele15_Ele8_CaloIdL_TrackIdL_IsoVL_v1',
#        'HLT_Ele15_IsoVVVL_PFHT450_CaloBTagCSV_4p5_v7',
#        'HLT_Ele15_IsoVVVL_PFHT450_PFMET50_v14',
#        'HLT_Ele15_IsoVVVL_PFHT450_v14', 'HLT_Ele15_IsoVVVL_PFHT600_v18',
#        'HLT_Ele15_WPLoose_Gsf_v1',
#        'HLT_Ele16_Ele12_Ele8_CaloIdL_TrackIdL_v7',
#        'HLT_Ele17_CaloIdM_TrackIdM_PFJet30_v14',
#        'HLT_Ele17_WPLoose_Gsf_v1', 'HLT_Ele200_CaloIdVT_GsfTrkIdT_v6',
#        'HLT_Ele20_WPLoose_Gsf_v4', 'HLT_Ele20_WPTight_Gsf_v4',
#        'HLT_Ele20_eta2p1_WPLoose_Gsf_v4',
#        'HLT_Ele23_CaloIdL_TrackIdL_IsoVL_PFJet30_v16',
#        'HLT_Ele23_CaloIdM_TrackIdM_PFJet30_v16',
#        'HLT_Ele23_Ele12_CaloIdL_TrackIdL_IsoVL_DZ_v17',
#        'HLT_Ele23_Ele12_CaloIdL_TrackIdL_IsoVL_v17',
#        'HLT_Ele24_eta2p1_WPTight_Gsf_LooseChargedIsoPFTau30_eta2p1_CrossL1_v11',
#        'HLT_Ele24_eta2p1_WPTight_Gsf_LooseChargedIsoPFTau30_eta2p1_TightID_CrossL1_v11',
#        'HLT_Ele24_eta2p1_WPTight_Gsf_MediumChargedIsoPFTau30_eta2p1_CrossL1_v11',
#        'HLT_Ele24_eta2p1_WPTight_Gsf_MediumChargedIsoPFTau30_eta2p1_TightID_CrossL1_v11',
#        'HLT_Ele24_eta2p1_WPTight_Gsf_TightChargedIsoPFTau30_eta2p1_CrossL1_v11',
#        'HLT_Ele24_eta2p1_WPTight_Gsf_TightChargedIsoPFTau30_eta2p1_TightID_CrossL1_v11',
#        'HLT_Ele250_CaloIdVT_GsfTrkIdT_v11',
#        'HLT_Ele27_Ele37_CaloIdL_MW_v2', 'HLT_Ele27_WPTight_Gsf_v14',
#        'HLT_Ele28_HighEta_SC20_Mass55_v11',
#        'HLT_Ele28_eta2p1_WPTight_Gsf_HT150_v11',
#        'HLT_Ele300_CaloIdVT_GsfTrkIdT_v11',
#        'HLT_Ele30_eta2p1_WPTight_Gsf_CentralPFJet35_EleCleaned_v11',
#        'HLT_Ele32_WPTight_Gsf_L1DoubleEG_v7', 'HLT_Ele32_WPTight_Gsf_v13',
#        'HLT_Ele35_WPTight_Gsf_L1EGMT_v3', 'HLT_Ele35_WPTight_Gsf_v7',
#        'HLT_Ele38_WPTight_Gsf_v7', 'HLT_Ele40_WPTight_Gsf_v7',
#        'HLT_Ele50_CaloIdVT_GsfTrkIdT_PFJet165_v16',
#        'HLT_Ele50_IsoVVVL_PFHT450_v14',
#        'HLT_Ele8_CaloIdL_TrackIdL_IsoVL_PFJet30_v14',
#        'HLT_Ele8_CaloIdM_TrackIdM_PFJet30_v16',
#        'HLT_FullTrack_Multiplicity100_v2',
#        'HLT_FullTrack_Multiplicity130_v2',
#        'HLT_FullTrack_Multiplicity155_v3',
#        'HLT_FullTrack_Multiplicity85_v3', 'HLT_HT300_Beamspot_v9',
#        'HLT_HT400_DisplacedDijet40_DisplacedTrack_v11', 'HLT_HT425_v8',
#        'HLT_HT430_DisplacedDijet40_DisplacedTrack_v11',
#        'HLT_HT430_DisplacedDijet60_DisplacedTrack_v11',
#        'HLT_HT450_Beamspot_v9',
#        'HLT_HT500_DisplacedDijet40_DisplacedTrack_v11',
#        'HLT_HT550_DisplacedDijet60_Inclusive_v11',
#        'HLT_HT650_DisplacedDijet60_Inclusive_v11',
#        'HLT_HcalCalibration_v5', 'HLT_HcalIsolatedbunch_v4',
#        'HLT_HcalNZS_v12', 'HLT_HcalPhiSym_v14',
#        'HLT_IsoMu20_eta2p1_LooseChargedIsoPFTau27_eta2p1_CrossL1_v10',
#        'HLT_IsoMu20_eta2p1_LooseChargedIsoPFTau27_eta2p1_TightID_CrossL1_v10',
#        'HLT_IsoMu20_eta2p1_LooseChargedIsoPFTauHPS27_eta2p1_CrossL1_v1',
#        'HLT_IsoMu20_eta2p1_MediumChargedIsoPFTau27_eta2p1_CrossL1_v10',
#        'HLT_IsoMu20_eta2p1_MediumChargedIsoPFTau27_eta2p1_TightID_CrossL1_v10',
#        'HLT_IsoMu20_eta2p1_TightChargedIsoPFTau27_eta2p1_CrossL1_v10',
#        'HLT_IsoMu20_eta2p1_TightChargedIsoPFTau27_eta2p1_TightID_CrossL1_v10',
#        'HLT_IsoMu20_v13',
#        'HLT_IsoMu24_eta2p1_MediumChargedIsoPFTau35_Trk1_TightID_eta2p1_Reg_CrossL1_v10',
#        'HLT_IsoMu24_eta2p1_MediumChargedIsoPFTau35_Trk1_eta2p1_Reg_CrossL1_v10',
#        'HLT_IsoMu24_eta2p1_MediumChargedIsoPFTau50_Trk30_eta2p1_1pr_v10',
#        'HLT_IsoMu24_eta2p1_MediumChargedIsoPFTauHPS35_Trk1_eta2p1_Reg_CrossL1_v1',
#        'HLT_IsoMu24_eta2p1_TightChargedIsoPFTau35_Trk1_TightID_eta2p1_Reg_CrossL1_v10',
#        'HLT_IsoMu24_eta2p1_TightChargedIsoPFTau35_Trk1_eta2p1_Reg_CrossL1_v10',
#        'HLT_IsoMu24_eta2p1_v13', 'HLT_IsoMu24_v11',
#        'HLT_IsoMu27_LooseChargedIsoPFTau20_Trk1_eta2p1_SingleL1_v3',
#        'HLT_IsoMu27_MET90_v1',
#        'HLT_IsoMu27_MediumChargedIsoPFTau20_Trk1_eta2p1_SingleL1_v3',
#        'HLT_IsoMu27_TightChargedIsoPFTau20_Trk1_eta2p1_SingleL1_v3',
#        'HLT_IsoMu27_v14', 'HLT_IsoMu30_v2', 'HLT_IsoTrackHB_v3',
#        'HLT_IsoTrackHE_v3', 'HLT_L1ETMHadSeeds_v1',
#        'HLT_L1MinimumBiasHF0OR_v3', 'HLT_L1MinimumBiasHF_OR_v2',
#        'HLT_L1NotBptxOR_v3', 'HLT_L1SingleMu18_v3', 'HLT_L1SingleMu25_v2',
#        'HLT_L1UnpairedBunchBptxMinus_v2',
#        'HLT_L1UnpairedBunchBptxPlus_v2',
#        'HLT_L1_CDC_SingleMu_3_er1p2_TOP120_DPHI2p618_3p142_v2',
#        'HLT_L2Mu10_NoVertex_NoBPTX3BX_v5',
#        'HLT_L2Mu10_NoVertex_NoBPTX_v6', 'HLT_L2Mu10_v7',
#        'HLT_L2Mu23NoVtx_2Cha_CosmicSeed_v1', 'HLT_L2Mu23NoVtx_2Cha_v1',
#        'HLT_L2Mu40_NoVertex_3Sta_NoBPTX3BX_v5',
#        'HLT_L2Mu45_NoVertex_3Sta_NoBPTX3BX_v4', 'HLT_L2Mu50_v2',
#        'HLT_MET105_IsoTrk50_v8', 'HLT_MET120_IsoTrk50_v8',
#        'HLT_MediumChargedIsoPFTau180HighPtRelaxedIso_Trk50_eta2p1_1pr_v9',
#        'HLT_MediumChargedIsoPFTau180HighPtRelaxedIso_Trk50_eta2p1_v10',
#        'HLT_MediumChargedIsoPFTau200HighPtRelaxedIso_Trk50_eta2p1_v10',
#        'HLT_MediumChargedIsoPFTau220HighPtRelaxedIso_Trk50_eta2p1_v10',
#        'HLT_MediumChargedIsoPFTau50_Trk30_eta2p1_1pr_MET100_v10',
#        'HLT_MediumChargedIsoPFTau50_Trk30_eta2p1_1pr_MET110_v6',
#        'HLT_MediumChargedIsoPFTau50_Trk30_eta2p1_1pr_MET120_v6',
#        'HLT_MediumChargedIsoPFTau50_Trk30_eta2p1_1pr_MET130_v6',
#        'HLT_MediumChargedIsoPFTau50_Trk30_eta2p1_1pr_MET140_v1',
#        'HLT_MediumChargedIsoPFTau50_Trk30_eta2p1_1pr_MET90_v10',
#        'HLT_MediumChargedIsoPFTau50_Trk30_eta2p1_1pr_v10',
#        'HLT_MonoCentralPFJet80_PFMETNoMu110_PFMHTNoMu110_IDTight_v18',
#        'HLT_MonoCentralPFJet80_PFMETNoMu120_PFMHTNoMu120_IDTight_v18',
#        'HLT_MonoCentralPFJet80_PFMETNoMu130_PFMHTNoMu130_IDTight_v17',
#        'HLT_MonoCentralPFJet80_PFMETNoMu140_PFMHTNoMu140_IDTight_v17',
#        'HLT_Mu10_TrkIsoVVL_DiPFJet40_DEta3p5_MJJ750_HTT350_PFMETNoMu60_v12',
#        'HLT_Mu12_DoublePFJets100_CaloBTagCSV_p79_v1',
#        'HLT_Mu12_DoublePFJets200_CaloBTagCSV_p79_v1',
#        'HLT_Mu12_DoublePFJets350_CaloBTagCSV_p79_v1',
#        'HLT_Mu12_DoublePFJets40MaxDeta1p6_DoubleCaloBTagCSV_p79_v1',
#        'HLT_Mu12_DoublePFJets40_CaloBTagCSV_p79_v1',
#        'HLT_Mu12_DoublePFJets54MaxDeta1p6_DoubleCaloBTagCSV_p79_v1',
#        'HLT_Mu12_DoublePFJets62MaxDeta1p6_DoubleCaloBTagCSV_p79_v1',
#        'HLT_Mu12_DoublePhoton20_v3',
#        'HLT_Mu12_TrkIsoVVL_Ele23_CaloIdL_TrackIdL_IsoVL_DZ_v13',
#        'HLT_Mu12_TrkIsoVVL_Ele23_CaloIdL_TrackIdL_IsoVL_v5',
#        'HLT_Mu12_v1', 'HLT_Mu15_IsoVVVL_PFHT450_CaloBTagCSV_4p5_v7',
#        'HLT_Mu15_IsoVVVL_PFHT450_PFMET50_v13',
#        'HLT_Mu15_IsoVVVL_PFHT450_v13', 'HLT_Mu15_IsoVVVL_PFHT600_v17',
#        'HLT_Mu15_v1', 'HLT_Mu17_Photon30_IsoCaloId_v4',
#        'HLT_Mu17_TrkIsoVVL_Mu8_TrkIsoVVL_DZ_Mass3p8_v4',
#        'HLT_Mu17_TrkIsoVVL_Mu8_TrkIsoVVL_DZ_Mass8_v4',
#        'HLT_Mu17_TrkIsoVVL_Mu8_TrkIsoVVL_DZ_v14',
#        'HLT_Mu17_TrkIsoVVL_Mu8_TrkIsoVVL_v13', 'HLT_Mu17_TrkIsoVVL_v11',
#        'HLT_Mu17_v11', 'HLT_Mu18_Mu9_DZ_v3',
#        'HLT_Mu18_Mu9_SameSign_DZ_v3', 'HLT_Mu18_Mu9_SameSign_v3',
#        'HLT_Mu18_Mu9_v3',
#        'HLT_Mu19_TrkIsoVVL_Mu9_TrkIsoVVL_DZ_Mass3p8_v2',
#        'HLT_Mu19_TrkIsoVVL_Mu9_TrkIsoVVL_DZ_Mass8_v2',
#        'HLT_Mu19_TrkIsoVVL_Mu9_TrkIsoVVL_DZ_v2',
#        'HLT_Mu19_TrkIsoVVL_Mu9_TrkIsoVVL_v2', 'HLT_Mu19_TrkIsoVVL_v2',
#        'HLT_Mu19_v2', 'HLT_Mu20_Mu10_DZ_v3',
#        'HLT_Mu20_Mu10_SameSign_DZ_v3', 'HLT_Mu20_Mu10_SameSign_v3',
#        'HLT_Mu20_Mu10_v3', 'HLT_Mu20_TkMu0_Phi_v6', 'HLT_Mu20_v11',
#        'HLT_Mu23_Mu12_DZ_v3', 'HLT_Mu23_Mu12_SameSign_DZ_v3',
#        'HLT_Mu23_Mu12_SameSign_v3', 'HLT_Mu23_Mu12_v3',
#        'HLT_Mu23_TrkIsoVVL_Ele12_CaloIdL_TrackIdL_IsoVL_DZ_v13',
#        'HLT_Mu23_TrkIsoVVL_Ele12_CaloIdL_TrackIdL_IsoVL_v5',
#        'HLT_Mu25_TkMu0_Onia_v6', 'HLT_Mu25_TkMu0_Phi_v6',
#        'HLT_Mu27_Ele37_CaloIdL_MW_v3', 'HLT_Mu27_v12',
#        'HLT_Mu30_TkMu0_Onia_v6', 'HLT_Mu37_Ele27_CaloIdL_MW_v3',
#        'HLT_Mu37_TkMu27_v3', 'HLT_Mu3_PFJet40_v14',
#        'HLT_Mu43NoFiltersNoVtx_Photon43_CaloIdL_v4',
#        'HLT_Mu48NoFiltersNoVtx_Photon48_CaloIdL_v4',
#        'HLT_Mu50_IsoVVVL_PFHT450_v13', 'HLT_Mu50_v12', 'HLT_Mu55_v2',
#        'HLT_Mu7p5_L2Mu2_Jpsi_v9', 'HLT_Mu7p5_L2Mu2_Upsilon_v9',
#        'HLT_Mu7p5_Track2_Jpsi_v10', 'HLT_Mu7p5_Track2_Upsilon_v10',
#        'HLT_Mu7p5_Track3p5_Jpsi_v10', 'HLT_Mu7p5_Track3p5_Upsilon_v10',
#        'HLT_Mu7p5_Track7_Jpsi_v10', 'HLT_Mu7p5_Track7_Upsilon_v10',
#        'HLT_Mu8_DiEle12_CaloIdL_TrackIdL_DZ_v16',
#        'HLT_Mu8_DiEle12_CaloIdL_TrackIdL_v16',
#        'HLT_Mu8_Ele8_CaloIdM_TrackIdM_Mass8_PFHT350_DZ_v17',
#        'HLT_Mu8_Ele8_CaloIdM_TrackIdM_Mass8_PFHT350_v17',
#        'HLT_Mu8_TrkIsoVVL_DiPFJet40_DEta3p5_MJJ750_HTT300_PFMETNoMu60_v13',
#        'HLT_Mu8_TrkIsoVVL_Ele23_CaloIdL_TrackIdL_IsoVL_DZ_v11',
#        'HLT_Mu8_TrkIsoVVL_Ele23_CaloIdL_TrackIdL_IsoVL_v9',
#        'HLT_Mu8_TrkIsoVVL_v11', 'HLT_Mu8_v11', 'HLT_OldMu100_v3',
#        'HLT_PFHT1050_v16', 'HLT_PFHT180_v15', 'HLT_PFHT250_v15',
#        'HLT_PFHT330PT30_QuadPFJet_75_60_45_40_TriplePFBTagDeepCSV_4p5_v1',
#        'HLT_PFHT330PT30_QuadPFJet_75_60_45_40_v7',
#        'HLT_PFHT350MinPFJet15_v7', 'HLT_PFHT350_v17', 'HLT_PFHT370_v15',
#        'HLT_PFHT380_SixPFJet32_DoublePFBTagCSV_2p2_v7',
#        'HLT_PFHT380_SixPFJet32_DoublePFBTagDeepCSV_2p2_v6',
#        'HLT_PFHT380_SixPFJet32_v7',
#        'HLT_PFHT430_SixPFJet40_PFBTagCSV_1p5_v7',
#        'HLT_PFHT430_SixPFJet40_v9', 'HLT_PFHT430_v15',
#        'HLT_PFHT500_PFMET100_PFMHT100_IDTight_v10',
#        'HLT_PFHT500_PFMET110_PFMHT110_IDTight_v10', 'HLT_PFHT510_v15',
#        'HLT_PFHT590_v15', 'HLT_PFHT680_v15',
#        'HLT_PFHT700_PFMET85_PFMHT85_IDTight_v10',
#        'HLT_PFHT700_PFMET95_PFMHT95_IDTight_v10', 'HLT_PFHT780_v15',
#        'HLT_PFHT800_PFMET75_PFMHT75_IDTight_v10',
#        'HLT_PFHT800_PFMET85_PFMHT85_IDTight_v10', 'HLT_PFHT890_v15',
#        'HLT_PFJet140_v17', 'HLT_PFJet15_v1', 'HLT_PFJet200_v17',
#        'HLT_PFJet25_v1', 'HLT_PFJet260_v18', 'HLT_PFJet320_v18',
#        'HLT_PFJet400_v18', 'HLT_PFJet40_v19', 'HLT_PFJet450_v19',
#        'HLT_PFJet500_v19', 'HLT_PFJet550_v9', 'HLT_PFJet60_v19',
#        'HLT_PFJet80_v18', 'HLT_PFJetFwd140_v16', 'HLT_PFJetFwd15_v1',
#        'HLT_PFJetFwd200_v16', 'HLT_PFJetFwd25_v1', 'HLT_PFJetFwd260_v17',
#        'HLT_PFJetFwd320_v17', 'HLT_PFJetFwd400_v17', 'HLT_PFJetFwd40_v17',
#        'HLT_PFJetFwd450_v17', 'HLT_PFJetFwd500_v17', 'HLT_PFJetFwd60_v17',
#        'HLT_PFJetFwd80_v16',
#        'HLT_PFMET100_PFMHT100_IDTight_CaloBTagCSV_3p1_v7',
#        'HLT_PFMET100_PFMHT100_IDTight_PFHT60_v7',
#        'HLT_PFMET110_PFMHT110_IDTight_CaloBTagCSV_3p1_v7',
#        'HLT_PFMET110_PFMHT110_IDTight_v18',
#        'HLT_PFMET120_PFMHT120_IDTight_CaloBTagCSV_3p1_v7',
#        'HLT_PFMET120_PFMHT120_IDTight_PFHT60_v7',
#        'HLT_PFMET120_PFMHT120_IDTight_v18',
#        'HLT_PFMET130_PFMHT130_IDTight_CaloBTagCSV_3p1_v7',
#        'HLT_PFMET130_PFMHT130_IDTight_v18',
#        'HLT_PFMET140_PFMHT140_IDTight_CaloBTagCSV_3p1_v7',
#        'HLT_PFMET140_PFMHT140_IDTight_v18', 'HLT_PFMET200_HBHECleaned_v7',
#        'HLT_PFMET200_HBHE_BeamHaloCleaned_v7',
#        'HLT_PFMET200_NotCleaned_v7', 'HLT_PFMET250_HBHECleaned_v7',
#        'HLT_PFMET300_HBHECleaned_v7',
#        'HLT_PFMETNoMu100_PFMHTNoMu100_IDTight_PFHT60_v7',
#        'HLT_PFMETNoMu110_PFMHTNoMu110_IDTight_v18',
#        'HLT_PFMETNoMu120_PFMHTNoMu120_IDTight_PFHT60_v7',
#        'HLT_PFMETNoMu120_PFMHTNoMu120_IDTight_v18',
#        'HLT_PFMETNoMu130_PFMHTNoMu130_IDTight_v17',
#        'HLT_PFMETNoMu140_PFMHTNoMu140_IDTight_v17',
#        'HLT_PFMETTypeOne100_PFMHT100_IDTight_PFHT60_v7',
#        'HLT_PFMETTypeOne110_PFMHT110_IDTight_v10',
#        'HLT_PFMETTypeOne120_PFMHT120_IDTight_PFHT60_v7',
#        'HLT_PFMETTypeOne120_PFMHT120_IDTight_v10',
#        'HLT_PFMETTypeOne130_PFMHT130_IDTight_v10',
#        'HLT_PFMETTypeOne140_PFMHT140_IDTight_v9',
#        'HLT_PFMETTypeOne200_HBHE_BeamHaloCleaned_v7',
#        'HLT_Photon120_R9Id90_HE10_IsoM_v13', 'HLT_Photon120_v12',
#        'HLT_Photon150_v5', 'HLT_Photon165_R9Id90_HE10_IsoM_v14',
#        'HLT_Photon175_v13', 'HLT_Photon200_v12',
#        'HLT_Photon20_HoverELoose_v9', 'HLT_Photon20_v1',
#        'HLT_Photon300_NoHE_v11', 'HLT_Photon30_HoverELoose_v9',
#        'HLT_Photon33_v4',
#        'HLT_Photon50_R9Id90_HE10_IsoM_EBOnly_PFJetsMJJ300DEta3_PFMET50_v3',
#        'HLT_Photon50_R9Id90_HE10_IsoM_v13', 'HLT_Photon50_v12',
#        'HLT_Photon60_R9Id90_CaloIdL_IsoL_DisplacedIdL_PFHT350MinPFJet15_v9',
#        'HLT_Photon60_R9Id90_CaloIdL_IsoL_DisplacedIdL_v4',
#        'HLT_Photon60_R9Id90_CaloIdL_IsoL_v4',
#        'HLT_Photon75_R9Id90_HE10_IsoM_EBOnly_CaloMJJ300_PFJetsMJJ400DEta3_v3',
#        'HLT_Photon75_R9Id90_HE10_IsoM_EBOnly_CaloMJJ400_PFJetsMJJ600DEta3_v3',
#        'HLT_Photon75_R9Id90_HE10_IsoM_EBOnly_PFJetsMJJ300DEta3_v3',
#        'HLT_Photon75_R9Id90_HE10_IsoM_EBOnly_PFJetsMJJ600DEta3_v3',
#        'HLT_Photon75_R9Id90_HE10_IsoM_v13', 'HLT_Photon75_v12',
#        'HLT_Photon90_R9Id90_HE10_IsoM_v13', 'HLT_Photon90_v12',
#        'HLT_Physics_part0_v7', 'HLT_Physics_part1_v7',
#        'HLT_Physics_part2_v7', 'HLT_Physics_part3_v7',
#        'HLT_Physics_part4_v7', 'HLT_Physics_part5_v7',
#        'HLT_Physics_part6_v7', 'HLT_Physics_part7_v7', 'HLT_Physics_v7',
#        'HLT_QuadPFJet103_88_75_15_BTagCSV_p013_VBF2_v7',
#        'HLT_QuadPFJet103_88_75_15_DoubleBTagCSV_p013_p08_VBF1_v7',
#        'HLT_QuadPFJet103_88_75_15_v3',
#        'HLT_QuadPFJet105_88_76_15_BTagCSV_p013_VBF2_v7',
#        'HLT_QuadPFJet105_88_76_15_v3',
#        'HLT_QuadPFJet105_90_76_15_DoubleBTagCSV_p013_p08_VBF1_v7',
#        'HLT_QuadPFJet111_90_80_15_BTagCSV_p013_VBF2_v7',
#        'HLT_QuadPFJet111_90_80_15_DoubleBTagCSV_p013_p08_VBF1_v7',
#        'HLT_QuadPFJet111_90_80_15_v3',
#        'HLT_QuadPFJet98_83_71_15_BTagCSV_p013_VBF2_v7',
#        'HLT_QuadPFJet98_83_71_15_DoubleBTagCSV_p013_p08_VBF1_v7',
#        'HLT_QuadPFJet98_83_71_15_v3', 'HLT_Random_v3', 'HLT_Rsq0p35_v13',
#        'HLT_Rsq0p40_v13', 'HLT_RsqMR300_Rsq0p09_MR200_4jet_v13',
#        'HLT_RsqMR300_Rsq0p09_MR200_v13',
#        'HLT_RsqMR320_Rsq0p09_MR200_4jet_v13',
#        'HLT_RsqMR320_Rsq0p09_MR200_v13',
#        'HLT_SingleJet30_Mu12_SinglePFJet40_v9',
#        'HLT_SinglePhoton10_Eta3p1ForPPRef_v8',
#        'HLT_SinglePhoton20_Eta3p1ForPPRef_v8',
#        'HLT_SinglePhoton30_Eta3p1ForPPRef_v8',
#        'HLT_Tau3Mu_Mu7_Mu1_TkMu1_IsoTau15_Charge1_v2',
#        'HLT_Tau3Mu_Mu7_Mu1_TkMu1_IsoTau15_v2',
#        'HLT_Tau3Mu_Mu7_Mu1_TkMu1_Tau15_Charge1_v2',
#        'HLT_Tau3Mu_Mu7_Mu1_TkMu1_Tau15_v2', 'HLT_TkMu100_v2',
#        'HLT_Trimuon5_3p5_2_Upsilon_Muon_v4',
#        'HLT_TrimuonOpen_5_3p5_2_Upsilon_Muon_v2',
#        'HLT_TripleJet110_35_35_Mjj650_PFMET110_v7',
#        'HLT_TripleJet110_35_35_Mjj650_PFMET120_v7',
#        'HLT_TripleJet110_35_35_Mjj650_PFMET130_v7',
#        'HLT_TripleMu_10_5_5_DZ_v9', 'HLT_TripleMu_12_10_5_v9',
#        'HLT_TripleMu_5_3_3_Mass3p8to60_DCA_v2',
#        'HLT_TripleMu_5_3_3_Mass3p8to60_DZ_v7',
#        'HLT_TriplePhoton_20_20_20_CaloIdLV2_R9IdVL_v2',
#        'HLT_TriplePhoton_20_20_20_CaloIdLV2_v2',
#        'HLT_TriplePhoton_30_30_10_CaloIdLV2_R9IdVL_v3',
#        'HLT_TriplePhoton_30_30_10_CaloIdLV2_v3',
#        'HLT_TriplePhoton_35_35_5_CaloIdLV2_R9IdVL_v3',
#        'HLT_TrkMu12_DoubleTrkMu5NoFiltersNoVtx_v5',
#        'HLT_TrkMu16_DoubleTrkMu6NoFiltersNoVtx_v11',
#        'HLT_TrkMu17_DoubleTrkMu8NoFiltersNoVtx_v12',
#        'HLT_UncorrectedJetE30_NoBPTX3BX_v5',
#        'HLT_UncorrectedJetE30_NoBPTX_v5',
#        'HLT_UncorrectedJetE60_NoBPTX3BX_v5',
#        'HLT_UncorrectedJetE70_NoBPTX3BX_v5',
#        'HLT_VBF_DoubleLooseChargedIsoPFTau20_Trk1_eta2p1_v1',
#        'HLT_VBF_DoubleMediumChargedIsoPFTau20_Trk1_eta2p1_v1',
#        'HLT_VBF_DoubleTightChargedIsoPFTau20_Trk1_eta2p1_v1',
#        'HLT_ZeroBias_Beamspot_v2', 'HLT_ZeroBias_FirstBXAfterTrain_v3',
#        'HLT_ZeroBias_FirstCollisionAfterAbortGap_v5',
#        'HLT_ZeroBias_FirstCollisionInTrain_v4',
#        'HLT_ZeroBias_IsolatedBunches_v5',
#        'HLT_ZeroBias_LastCollisionInTrain_v3', 'HLT_ZeroBias_part0_v6',
#        'HLT_ZeroBias_part1_v6', 'HLT_ZeroBias_part2_v6',
#        'HLT_ZeroBias_part3_v6', 'HLT_ZeroBias_part4_v6',
#        'HLT_ZeroBias_part5_v6', 'HLT_ZeroBias_part6_v6',
#        'HLT_ZeroBias_part7_v6', 'HLT_ZeroBias_v6', 'HLTriggerFinalPath',
#        'HLTriggerFirstPath'], dtype=object)
